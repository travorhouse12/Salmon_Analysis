# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Read in the CSV Data
df = pd.read_csv('original_salmon.csv')
# Out:
# /Users/macbook/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (7,35,54,55,57,58,63,69,70,72,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Analyze the data
df
# Out:
#                  Recovery Domain                                Esu Name  \
# 0              Interior Columbia     Middle Columbia River Steelhead DPS
# 1              Interior Columbia     Middle Columbia River Steelhead DPS
# 2              Interior Columbia     Middle Columbia River Steelhead DPS
# 3              Interior Columbia     Middle Columbia River Steelhead DPS
# 4              Interior Columbia     Middle Columbia River Steelhead DPS
# ...                          ...                                     ...
# 66423  Willamette/Lower Columbia  Steelhead (Upper Willamette River DPS)
# 66424  Willamette/Lower Columbia  Steelhead (Upper Willamette River DPS)
# 66425  Willamette/Lower Columbia  Steelhead (Upper Willamette River DPS)
# 66426  Willamette/Lower Columbia  Steelhead (Upper Willamette River DPS)
# 66427  Willamette/Lower Columbia  Steelhead (Upper Willamette River DPS)
#
#                    Major Population Group Common Population Name  \
# ...

# %%
# See what values live inside the column Species to identify any duplicates
a = df['Species'].unique()
print(sorted(a))
# Out:
# [' ', 'Chinook', 'Chinook salmon', 'Chum', 'Chum salmon', 'Coho', 'Coho salmon', 'Sockeye', 'Steelhead', 'Summer Chum', 'chinook', 'steelhead']

# %%
# Create a new dataframe that only displays the values for chinook salmon
salmon = df[df['Species'].isin(['Chinook salmon','chinook','Chinook'])]

# %%
# Ensure that we have the appropriate values
b = salmon['Species'].unique()

# %%
# Create a new dataframe to hold only the rows that we need for our analysis
salmon_1 = salmon[['Brood Year','Nwr Population Name','Number Of Spawners','Start Year','End Year','Stream Name']]

# %%
salmon_1.to_csv("salmon_1.csv")

# %%
# Export as a CSV
salmon.to_csv('salmon_data.csv')
