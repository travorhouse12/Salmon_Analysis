# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
db_string = f"postgresql://postgres:Tom&Sybil13@127.0.0.1:5432/Salmon_Analysis"

# %%
engine = create_engine(db_string)

# %%
df = pd.read_sql_query('select * from "salmon_data"', con=engine)
df.head(10)
# Out:
#     id  Brood Year                                Nwr Population Name  \
# 0  616        1975  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 1  617        1976  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 2  618        1977  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 3  619        1978  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 4  620        1979  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 5  621        1980  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 6  622        1981  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 7  623        1982  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 8  624        1983  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 9  625        1984  Chinook Salmon (Snake River Fall-run ESU) - Sn...
#
#    Number of Spawners  Start Year  End Year  Effective Catch  Fracwild
# 0              1000.0      1975.0    2008.0           1851.0      1.00
# ...
