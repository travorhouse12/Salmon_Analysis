# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# pgAdmnin interface

# %%
# Pull in Data
df = pd.read_csv('Data/salmon_preprocessed.csv')
df.head()
# Out:
#    Brood_Year                                Nwr_Population_Name  \
# 0        1977  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 1        1978  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 2        1979  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 3        1980  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 4        1981  Chinook Salmon (Snake River Fall-run ESU) - Sn...
#
#    Number_Of_Spawners  Start_Year  End_Year  Effective_Catch  Fracwild  \
# 0               600.0      1975.0    2008.0           1097.0       1.0
# 1               640.0      1975.0    2008.0           1011.0       1.0
# 2               500.0      1975.0    2008.0            514.0       1.0
# 3               450.0      1975.0    2008.0            159.0       1.0
# 4               340.0      1975.0    2008.0            150.0       1.0
#
#    Wild_Spawners  Spawners_Prev_Yr  Eff_Catch_Prev_Yr  Fracwild_Prev_Yr  \
# 0          600.0             470.0              617.0               1.0
# 1          640.0             600.0             1097.0               1.0
# 2          500.0             640.0             1011.0               1.0
# 3          450.0             500.0              514.0               1.0
# 4          340.0             450.0              159.0               1.0
#
#    Wild_Spawners_Prev_Yr  Spawners_Two_Yrs_Prior  Eff_Catch_Two_Yrs_Prior  \
# 0                  470.0                  1000.0                      1.0
# 1                  600.0                   470.0                      1.0
# 2                  640.0                   600.0                      1.0
# 3                  500.0                   640.0                      1.0
# 4                  450.0                   500.0                      1.0
#
#    Fracwild_Two_Yrs_Prior  Wild_Spawners_Two_Yrs_Prior
# 0                  1851.0                       1000.0
# 1                   617.0                        470.0
# 2                  1097.0                        600.0
# 3                  1011.0                        640.0
# 4                   514.0                        500.0

# %%
# Isolate the Stream we want to teach the model on and reset index
target_df = df.loc[df['Nwr_Population_Name'] == 'Chinook Salmon (Puget Sound ESU) - White River']
target_df.reset_index(drop=True, inplace=True)
target_df.head()
# Out:
#    Brood_Year                             Nwr_Population_Name  \
# 0        1967  Chinook Salmon (Puget Sound ESU) - White River
# 1        1968  Chinook Salmon (Puget Sound ESU) - White River
# 2        1969  Chinook Salmon (Puget Sound ESU) - White River
# 3        1970  Chinook Salmon (Puget Sound ESU) - White River
# 4        1971  Chinook Salmon (Puget Sound ESU) - White River
#
#    Number_Of_Spawners  Start_Year  End_Year  Effective_Catch  Fracwild  \
# 0               688.0         NaN       NaN            478.0       1.0
# 1               513.0         NaN       NaN            373.0       1.0
# 2               548.0         NaN       NaN            325.0       1.0
# 3               659.0         NaN       NaN            510.0       1.0
# 4               394.0         NaN       NaN            238.0       1.0
#
#    Wild_Spawners  Spawners_Prev_Yr  Eff_Catch_Prev_Yr  Fracwild_Prev_Yr  \
# 0          688.0            1828.0              178.0              0.23
# 1          513.0             688.0              478.0              1.00
# 2          548.0             513.0              373.0              1.00
# 3          659.0             548.0              325.0              1.00
# 4          394.0             659.0              510.0              1.00
#
#    Wild_Spawners_Prev_Yr  Spawners_Two_Yrs_Prior  Eff_Catch_Two_Yrs_Prior  \
# 0                 420.44                  1184.0                     0.23
# 1                 688.00                  1828.0                     0.23
# 2                 513.00                   688.0                     1.00
# 3                 548.00                   513.0                     1.00
# 4                 659.00                   548.0                     1.00
#
#    Fracwild_Two_Yrs_Prior  Wild_Spawners_Two_Yrs_Prior
# 0                    68.0                       272.32
# 1                   178.0                       420.44
# 2                   478.0                       688.00
# 3                   373.0                       513.00
# 4                   325.0                       548.00

# %%
# Delete first two rows and reset index
target_df = target_df.drop(target_df.index[[0,1]])
number_Of_Spawners  Start_Year  End_Year  Effective_Catch  Fracwild  \
# 0                548.0         NaN       NaN            325.0      1.00
# 1                659.0         NaN       NaN            510.0      1.00
# 2                394.0         NaN       NaN            238.0      1.00
# 3                442.0         NaN       NaN            350.0      1.00
# 4                169.0         NaN       NaN             95.0      1.00
# 5                444.0         NaN       NaN            269.0      1.00
# 6                490.0         NaN       NaN            338.0      1.00
# 7                251.0         NaN       NaN            285.0      1.00
# 8                 77.0         NaN       NaN             79.0      1.00
# 9                141.0         NaN       NaN            217.0      1.00
# 10               103.0         NaN       NaN            139.0      1.00
# 11                58.0         NaN       NaN             33.0      1.00
# 12               183.0         NaN       NaN            190.0      1.00
# 13                21.0         NaN       NaN             25.0      1.00
# 14                27.0         NaN       NaN             26.0      0.99
# 15                 7.0         NaN       NaN              4.0      0.94
# 16                33.0         NaN       NaN             25.0      0.99
# 17                11.0         NaN       NaN              3.0      0.69
# 18               118.0         NaN       NaN             58.0      0.99
# 19               164.0         NaN       NaN            106.0      0.96
# 20                95.0         NaN       NaN             57.0      0.96
# 21               299.0         NaN       NaN            178.0      0.99
# 22               231.0         NaN       NaN            512.0      0.99
# 23               444.0         NaN       NaN            180.0      0.61
# 24               444.0         NaN       NaN            233.0      0.67
# 25               494.0         NaN       NaN            115.0      0.47
# 26               713.0         NaN       NaN            166.0      0.50
# 27               659.0         NaN       NaN            285.0      0.93
# 28               476.0         NaN       NaN            232.0      0.92
# 29               422.0         NaN       NaN             95.0      0.86
# 30               750.0         NaN       NaN            176.0      0.91
# 31              1496.0         NaN       NaN            453.0      0.94
# 32              2131.0         NaN       NaN           3384.0      0.95
# 33               823.0         NaN       NaN            810.0      0.85
# 34              1480.0         NaN       NaN            544.0      0.82
# 35              1959.0         NaN       NaN            837.0      0.83
# 36              1846.0         NaN       NaN            771.0      0.73
# 37              2418.0         NaN       NaN            272.0      0.68
# 38              4591.0         NaN       NaN            511.0      0.62
# 39              1967.0         NaN       NaN            289.0      0.73
# 40               984.0         NaN       NaN            169.0      0.73
# 41               932.0         NaN       NaN             67.0      0.59
#
#     Wild_Spawners  Spawners_Prev_Yr  Eff_Catch_Prev_Yr  Fracwild_Prev_Yr  \
# 0          548.00             513.0              373.0              1.00
# 1          659.00             548.0              325.0              1.00
# 2          394.00             659.0              510.0              1.00
# 3          442.00             394.0              238.0              1.00
# 4          169.00             442.0              350.0              1.00
# 5          444.00             169.0               95.0              1.00
# 6          490.00             444.0              269.0              1.00
# 7          251.00             490.0              338.0              1.00
# 8           77.00             251.0              285.0              1.00
# 9          141.00              77.0               79.0              1.00
# 10         103.00             141.0              217.0              1.00
# 11          58.00             103.0              139.0              1.00
# 12         183.00              58.0               33.0              1.00
# 13          21.00             183.0              190.0              1.00
# 14          26.73              21.0               25.0              1.00
# 15           6.58              27.0               26.0              0.99
# 16          32.67               7.0                4.0              0.94
# 17           7.59              33.0               25.0              0.99
# 18         116.82              11.0                3.0              0.69
# 19         157.44             118.0               58.0              0.99
# 20          91.20             164.0              106.0              0.96
# 21         296.01              95.0               57.0              0.96
# 22         228.69             299.0              178.0              0.99
# 23         270.84             231.0              512.0              0.99
# 24         297.48             444.0              180.0              0.61
# 25         232.18             444.0              233.0              0.67
# 26         356.50             494.0              115.0              0.47
# 27         612.87             713.0              166.0              0.50
# 28         437.92             659.0              285.0              0.93
# 29         362.92             476.0              232.0              0.92
# 30         682.50             422.0               95.0              0.86
# 31        1406.24             750.0              176.0              0.91
# 27                   115.0                       232.18
# 28                   166.0                       356.50
# 29                   285.0                       612.87
# 30                   232.0                       437.92
# 31                    95.0                       362.92
# 32                   176.0                       682.50
# 33                   453.0                      1406.24
# 34                  3384.0                      2024.45
# 35                   810.0                       699.55
# 36                   544.0                      1213.60
# 37                   837.0                      1625.97
# 38                   771.0                      1347.58
# 39                   272.0                      1644.24
# 40                   511.0                      2846.42
# 41                   289.0                      1435.91

# %%
# Scale idependent variables
scaler = StandardScaler()
scaled_target = target_df [[
    'Spawners_Prev_Yr', 
    'Eff_Catch_Prev_Yr', 
    'Fracwild_Prev_Yr',
    'Wild_Spawners_Prev_Yr',
    'Spawners_Two_Yrs_Prior',
    'Eff_Catch_Two_Yrs_Prior',
    'Fracwild_Two_Yrs_Prior',
    'Wild_Spawners_Two_Yrs_Prior']].values.tolist()

scaled_data =  scaler.fit_transform(scaled_target)
scaled_data
# Out:
# array([[-2.17245864e-01,  7.81035550e-02,  7.50994947e-01,
#         -8.15474867e-02, -1.03758703e-02,  7.13404739e-01,
#          2.65614593e-01,  2.01564736e-01],
#        [-1.77471120e-01, -1.40303051e-02,  7.50994947e-01,
#         -2.51681819e-02, -2.09495052e-01,  7.13404739e-01,
#          6.40035163e-02, -8.04056890e-02],
#        [-5.13283601e-02,  3.41068947e-01,  7.50994947e-01,
#          1.53634756e-01, -1.69671215e-01,  7.13404739e-01,
#         -2.81615472e-02, -2.40116039e-02],
#        [-3.52479993e-01, -1.81022927e-01,  7.50994947e-01,
#         -2.73237123e-01, -4.33727632e-02,  7.13404739e-01,
#          3.27057968e-01,  1.54838208e-01],
#        [-2.97931773e-01,  3.39560804e-02,  7.50994947e-01,
#         -1.95916934e-01, -3.44896095e-01,  7.13404739e-01,
#         -1.95210725e-01, -2.72145578e-01],
#        [-6.08174776e-01, -4.55505051e-01,  7.50994947e-01,
#         -6.35675511e-01, -2.90280548e-01,  7.13404739e-01,
#          1.98410901e-02, -1.94805119e-01],
#        [-2.95658930e-01, -1.21519809e-01,  7.50994947e-01,
#         -1.92695259e-01, -6.00906471e-01,  7.13404739e-01,
#         -4.69785810e-01, -6.34678982e-01],
#        [-2.43383553e-01,  1.09226154e-02,  7.50994947e-01,
#         -1.18596744e-01, -2.88004900e-01,  7.13404739e-01,
#         -1.35687455e-01, -1.91582599e-01],
#        [-5.14988233e-01, -9.08085218e-02,  7.50994947e-01,
#         -5.03586854e-01, -2.35665001e-01,  7.13404739e-01,
#         -3.20017581e-03, -1.17464659e-01],
#        [-7.12725532e-01, -4.86216338e-01,  7.50994947e-01,
#         -7.83872540e-01, -5.07604912e-01,  7.13404739e-01,
#         -1.04965767e-01, -5.02555697e-01],
#        [-6.39994571e-01, -2.21331490e-01,  7.50994947e-01,
#         -6.80778955e-01, -7.05586269e-01,  7.13404739e-01,
#         -5.00507497e-01, -7.82914862e-01],
#        [-6.83178579e-01, -3.71049013e-01,  7.50994947e-01,
#         -7.41990771e-01, -6.32765540e-01,  7.13404739e-01,
#          7.93268324e-02,  1.80697271e-02, -2.63067998e+00,
#         -3.33458320e-01, -3.32567812e-01],
#        [-2.59293450e-01, -1.92539659e-01,  2.19764837e-01,
#         -2.02489150e-01, -4.33727632e-02,  2.45232879e-01,
#         -1.04965767e-01,  8.05108045e-02],
#        [-3.20660198e-01, -4.55505051e-01, -1.78657745e-01,
#         -3.23301946e-01, -2.51594536e-01,  1.78351185e-01,
#         -2.06731358e-01, -2.01379058e-01],
#        [ 5.20859743e-02, -3.00029163e-01,  1.53361073e-01,
#          1.91489432e-01, -3.13037026e-01, -2.22938981e-01,
#         -4.69785810e-01, -3.22223525e-01],
#        [ 8.99856232e-01,  2.31659989e-01,  3.52572365e-01,
#          1.35731680e+00,  6.01692111e-02,  1.11469491e-01,
#         -3.14257265e-01,  1.92702808e-01],
#        [ 1.62148373e+00,  5.85758382e+00,  4.18976128e-01,
#          2.35315252e+00,  9.08985836e-01,  3.12114573e-01,
#          2.17611955e-01,  1.35883581e+00],
#        [ 1.35044726e-01,  9.16905573e-01, -2.45061509e-01,
#          2.18954208e-01,  1.63150401e+00,  3.78996268e-01,
#          5.84544114e+00,  2.35493259e+00],
#        [ 8.81673492e-01,  4.06330432e-01, -4.44272800e-01,
#          1.04700511e+00,  1.43230355e-01, -2.89820675e-01,
#          9.03089615e-01,  2.20174784e-01],
#        [ 1.42601927e+00,  9.68730869e-01, -3.77869037e-01,
#          1.71126608e+00,  8.90780653e-01, -4.90465758e-01,
#          3.92341555e-01,  1.04844277e+00],
#        [ 1.29760367e+00,  8.42046812e-01, -1.04190667e+00,
#          1.26282509e+00,  1.43579830e+00, -4.23584064e-01,
#          9.54932463e-01,  1.71287788e+00],
#        [ 1.94763663e+00, -1.15761442e-01, -1.37392549e+00,
#          1.74069608e+00,  1.30722420e+00, -1.09240101e+00,
#          8.28205501e-01,  1.26431932e+00],
#        [ 4.41708002e+00,  3.42988403e-01, -1.77234808e+00,
#          3.67721244e+00,  1.95805947e+00, -1.42680948e+00,
#         -1.29927138e-01,  1.74231559e+00],
#        [ 1.43511064e+00, -8.31307002e-02, -1.04190667e+00,
#          1.40511035e+00,  4.43055079e+00, -1.82809964e+00,
#          3.28978074e-01,  3.67933962e+00],
#        [ 3.18008548e-01, -3.13465350e-01, -1.04190667e+00,
#          2.49189624e-01,  1.44490089e+00, -1.09240101e+00,
#         -9.72853448e-02,  1.40664188e+00]])

# %%
# Create DatsFrame with scaled data
scaled_df = pd.DataFrame(
    data=scaled_data,
    columns=['Spawners_Prev_Yr_Sc', 
        'Eff_Catch_Prev_Yr_Sc', 
        'Fracwild_Prev_Yr_Sc',
        'Wild_Spawners_Prev_Yr_Sc',
        'Spawners_Two_Yrs_Prior_Sc',
        'Eff_Catch_Two_Yrs_Prior_Sc',
        'Fracwild_Two_Yrs_Prior_Sc',
        'Wild_Spawners_Two_Yrs_Prior_Sc'],
        index=target_df.index)

# %%
# Delete columns of unscaled independent variables
target_df.drop(columns = [
    'Spawners_Prev_Yr', 
    'Eff_Catch_Prev_Yr', 
    'Fracwild_Prev_Yr',
    'Wild_Spawners_Prev_Yr',
    'Spawners_Two_Yrs_Prior',
    'Eff_Catch_Two_Yrs_Prior',
    'Fracwild_Two_Yrs_Prior',
    'Wild_Spawners_Two_Yrs_Prior'],
    inplace=True)

# Combine target_df and scaled_df
scaled_target_df = pd.merge(target_df, scaled_df, left_index=True, right_index=True)
scaled_target_df.head()
# Out:
#    Brood_Year                             Nwr_Population_Name  \
# 0        1969  Chinook Salmon (Puget Sound ESU) - White River
# 1        1970  Chinook Salmon (Puget Sound ESU) - White River
# 2        1971  Chinook Salmon (Puget Sound ESU) - White River
# 3        1972  Chinook Salmon (Puget Sound ESU) - White River
# 4        1973  Chinook Salmon (Puget Sound ESU) - White River
#
#    Number_Of_Spawners  Start_Year  End_Year  Effective_Catch  Fracwild  \
# 0               548.0         NaN       NaN            325.0       1.0
# 1               659.0         NaN       NaN            510.0       1.0
# 2               394.0         NaN       NaN            238.0       1.0
# 3               442.0         NaN       NaN            350.0       1.0
# 4               169.0         NaN       NaN             95.0       1.0
#
#    Wild_Spawners  Spawners_Prev_Yr_Sc  Eff_Catch_Prev_Yr_Sc  \
# 0          548.0            -0.217246              0.078104
# 1          659.0            -0.177471             -0.014030
# 2          394.0            -0.051328              0.341069
# 3          442.0            -0.352480             -0.181023
# 4          169.0            -0.297932              0.033956
#
#    Fracwild_Prev_Yr_Sc  Wild_Spawners_Prev_Yr_Sc  Spawners_Two_Yrs_Prior_Sc  \
# 0             0.750995                 -0.081547                  -0.010376
# 1             0.750995                 -0.025168                  -0.209495
# 2             0.750995                  0.153635                  -0.169671
# 3             0.750995                 -0.273237                  -0.043373
# 4             0.750995                 -0.195917                  -0.344896
#
#    Eff_Catch_Two_Yrs_Prior_Sc  Fracwild_Two_Yrs_Prior_Sc  \
# 0                    0.713405                   0.265615
# 1                    0.713405                   0.064004
# 2                    0.713405                  -0.028162
# 3                    0.713405                   0.327058
# 4                    0.713405                  -0.195211
#
#    Wild_Spawners_Two_Yrs_Prior_Sc
# 0                        0.201565
# 1                       -0.080406
# 2                       -0.024012
# 3                        0.154838
# 4                       -0.272146

# %%
# Create our Feature
X = scaled_target_df.drop(columns = ['Nwr_Population_Name', 'Start_Year', 'End_Year', 'Effective_Catch', 'Fracwild', 'Number_Of_Spawners', 'Wild_Spawners'])

# Create our Target
y = scaled_target_df['Wild_Spawners']

# %%
# Split data into test and train
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#Counter(y_train)

# %%
# Set up a regression ML model
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# %%
# Score the model
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# Square root of the mean squared
print('Root Mean Squared error of is:',np.sqrt(mean_squared_error(y_test,y_pred)))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [   2.12539657 1048.35505995 -349.3177448    43.1499541   142.75371879
#  -721.85947769   -9.35497244  158.66817241  394.7828315 ]
# Mean squared error: 1132760.01
# Root Mean Squared error of is: 1064.3119908658377
# Coefficient of determination: -2.65

# %%
# year = target_df.Brood_Year.values.reshape(-1, 1)

# %%
# plt.scatter(year, y)
# plt.plot(year, y_pred, color='red')
# plt.show()
