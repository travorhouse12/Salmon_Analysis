# %%
import pandas as pd
import numpy as np
import re

# %%
big_wood_file = ("big_wood_river.csv")
big_wood_river_df = pd.read_csv(big_wood_file)


big_wood_river_df.head(10)
# Out:
#         Name              Height Capacity (MW) Province/State(s)  \
# 0  Magic Dam  128 ft (39 m)[128]        9[129]             Idaho
#
#                                          Coordinates Year of completion  \
# 0  43°15′0″N 114°22′12″W﻿ / ﻿43.25000°N 114.37000...          1910[128]
#
#                                       Owner Reservoir formed          Stream
# 0  Magic Reservoir Hydroelectric, Inc.[128]  Magic Reservoir  Big Wood River

# %%
blackfoot_file = ("blackfoot_river.csv")
blackfoot_river_df = pd.read_csv(blackfoot_file)

blackfoot_river_df.head()
# Out:
#             Name            Height  Capacity (MW) Province/State(s)  \
# 0  Blackfoot Dam  44 ft (13 m)[84]              0             Idaho
#
#                                          Coordinates Year of completion  \
# 0  43°0′0″N 111°42′36″W﻿ / ﻿43.00000°N 111.71000°...           1911[85]
#
#                                         Owner     Reservoir formed  \
# 0  United States Bureau of Indian Affairs[85]  Blackfoot Reservoir
#
#             Stream
# 0  Blackfoot River

# %%
boise_file = ("boise_river.csv")
boise_df = pd.read_csv(boise_file)

boise_df = boise_df.drop(['Image'], axis=1)

boise_df["Stream"] = ["Boise River", "Boise River", "Boise River", "Boise River"]

boise_df.head()
# Out:
#                              Name          Height Capacity (MW)  \
# 0               Arrowrock Dam[97]  350 ft (110 m)        15[98]
# 1              Lucky Peak Dam[99]  340 ft (100 m)   101.25[100]
# 2  Boise River Diversion Dam[101]    68 ft (21 m)       3.3[98]
# 3                 Barber Dam[102]   25 ft (7.6 m)     4.14[103]
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho   43°36′0″N 115°55′12″W﻿ / ﻿43.60000°N 115.92000°W
# 1             Idaho   43°31′12″N 116°03′0″W﻿ / ﻿43.52000°N 116.05000°W
# 2             Idaho  43°31′48″N 116°05′24″W﻿ / ﻿43.53000°N 116.09000°W
# 3             Idaho  43°34′12″N 116°07′12″W﻿ / ﻿43.57000°N 116.12000°W
#
#    Year of completion                                  Owner  \
# 0                1915    United States Bureau of Reclamation
# 1                1955  United States Army Corps of Engineers
# 2                1908    United States Bureau of Reclamation
# ...

# %%
bull_file = ("bull.csv")
bull_df = pd.read_csv(bull_file)

bull_df = bull_df.drop(['Image'], axis=1)

bull_df["Stream"] = ["Bull River"]

bull_df.head()
# Out:
#                   Name        Height Capacity (MW) Province/State(s)  \
# 0  Aberfeldie Dam[143]  90 ft (27 m)       24[144]  British Columbia
#
#                                         Coordinates   Year of completion  \
# 0  49°29′58″N 115°21′3″W﻿ / ﻿49.49944°N 115.35083°W  1922 (rebuilt 1953)
#
#       Owner     Reservoir formed      Stream
# 0  BC Hydro  Aberfeldie Dam Pool  Bull River

# %%
bumping_file = ("bumping.csv")
bumping_df = pd.read_csv(bumping_file)

bumping_df = bumping_df.drop(['Image'], axis=1)

bumping_df["Stream"] = ["Bumping River"]

bumping_df.head()
# Out:
#                Name             Height Capacity (MW) Province/State(s)  \
# 0  Bumping Lake Dam  60 ft (18 m)[177]        0[178]        Washington
#
#                                          Coordinates Year of completion Owner  \
# 0  46°52′16″N 121°17′58″W﻿ / ﻿46.87111°N 121.29944°W          1910[177]  USBR
#
#       Reservoir formed         Stream
# 0  Raised Bumping Lake  Bumping River

# %%
burnt_river_file = ("burnt_river.csv")
burnt_df = pd.read_csv(burnt_river_file)

burnt_df = burnt_df.drop(['Image'], axis=1)

burnt_df["Stream"] = ["Burnt River"]

burnt_df.head()
# Out:
#                   Name        Height      Capacity (MW) Province/State(s)  \
# 0  Unity Dam[112][113]  82 ft (25 m)  proposed 0.8[114]            Oregon
#
#                                         Coordinates  Year of completion  \
# 0  43°30′0″N 118°10′48″W﻿ / ﻿43.50000°N 118.18000°W                1938
#
#                                  Owner Reservoir formed       Stream
# 0  United States Bureau of Reclamation  Unity Reservoir  Burnt River

# %%
camas_file = ("camas_creek.csv")
camas_df = pd.read_csv(camas_file)

camas_df = camas_df.drop(['Image'], axis = 1)

camas_df["Stream"] = ["Camas Creek"]

camas_df.head()
# Out:
#                           Name              Height  Capacity (MW)  \
# 0  Mormon Dam (McKinney Creek)  23 ft (7.0 m)[130]              0
#
#   Province/State(s)                                       Coordinates  \
# 0             Idaho  43°16′48″N 114°48′0″W﻿ / ﻿43.28000°N 114.80000°W
#
#    Year of completion                                        Owner  \
# 0                1908  Twin Lakes Reservoir and Irrigation Company
#
#    Reservoir formed       Stream
# 0  Mormon Reservoir  Camas Creek

# %%
chelan_file = ("chelan.csv")
chelan_df = pd.read_csv(chelan_file)

chelan_df = chelan_df.drop(['Image'], axis = 1)

chelan_df["Stream"] = ["Chelan River"]

chelan_df.head()
# Out:
#               Name             Height Capacity (MW) Province/State(s)  \
# 0  Lake Chelan Dam  40 ft (12 m)[226]     59.2[226]        Washington
#
#                                          Coordinates      Year of completion  \
# 0  47°50′04″N 120°00′45″W﻿ / ﻿47.83444°N 120.01250°W  1892–1903 / 1927[n 24]
#
#                                    Owner    Reservoir formed        Stream
# 0  Chelan County Public Utility District  Raised Lake Chelan  Chelan River

# %%
cle_elum_file = ("cle_elum.csv")
cle_elum_df = pd.read_csv(cle_elum_file)

cle_elum_df = cle_elum_df.drop(['Image'], axis = 1)

cle_elum_df["Stream"] = ["Cle Elum River"]

cle_elum_df.head()
# Out:
#            Name              Height Capacity (MW) Province/State(s)  \
# 0  Cle Elum Dam  165 ft (50 m)[177]        0[178]        Washington
#
#                                         Coordinates Year of completion Owner  \
# 0  47°14′49″N 121°4′23″W﻿ / ﻿47.24694°N 121.07306°W          1933[177]  USBR
#
#        Reservoir formed          Stream
# 0  Raised Cle Elum Lake  Cle Elum River

# %%
coast_fork_willamette_file = ("coast_fork_willamette.csv")
coast_fork_willamette_df = pd.read_csv(coast_fork_willamette_file)

coast_fork_willamette_df = coast_fork_willamette_df.drop(['Image'], axis = 1)

coast_fork_willamette_df["Stream"] = ["Coast Fork Willamette River", "Coast Fork Willamette River"]

coast_fork_willamette_df.head()
# Out:
#                      Name              Height Capacity (MW) Province/State(s)  \
# 0       Cottage Grove Dam   95 ft (29 m)[203]             0            Oregon
# 1  Dorena Dam (Row River)  145 ft (44 m)[203]     7.51[204]            Oregon
#
#                                          Coordinates Year of completion  \
# 0  43°42′58″N 123°03′03″W﻿ / ﻿43.71611°N 123.05083°W          1942[203]
# 1   43°46′48″N 122°57′0″W﻿ / ﻿43.78000°N 122.95000°W          1949[203]
#
#    Owner    Reservoir formed                       Stream
# 0  USACE  Cottage Grove Lake  Coast Fork Willamette River
# 1  USACE         Dorena Lake  Coast Fork Willamette River

# %%
columbia_river_main_file = ("columbia_river_main.csv")
columbia_river_main_df = pd.read_csv(columbia_river_main_file)


columbia_river_main_df.head()
# Out:
#                Name             Height Capacity (MW) Province/State(s)  \
# 0          Mica Dam  240 m (790 ft)[4]      2,805[5]  British Columbia
# 1    Revelstoke Dam  175 m (574 ft)[6]      2,480[5]  British Columbia
# 2   Keenleyside Dam   52 m (171 ft)[7]        185[8]  British Columbia
# 3  Grand Coulee Dam  550 ft (170 m)[9]      6,809[9]        Washington
# 4  Chief Joseph Dam  236 ft (72 m)[10]     2,620[11]        Washington
#
#                                          Coordinates Year of completion  \
# 0  .mw-parser-output .geo-default,.mw-parser-outp...               1973
# 1  51°02′57″N 118°11′36″W﻿ / ﻿51.04917°N 118.19333°W               1984
# 2  49°20′18″N 117°46′18″W﻿ / ﻿49.33833°N 117.77167°W               1968
# 3  47°57′26″N 118°58′39″W﻿ / ﻿47.95722°N 118.97750°W  1941 / 1974 [n 1]
# 4  47°59′42″N 119°38′19″W﻿ / ﻿47.99500°N 119.63861°W               1955
#
#       Owner            Reservoir formed                    Stream
# ...

# %%
cowlitz_file = ("cowlitz.csv")
cowlitz_df = pd.read_csv(cowlitz_file)

cowlitz_df = cowlitz_df.drop(['Image='], axis = 1)

cowlitz_df["Stream"] = ["Cowlitz River", "Cowlitz River", "Cowlitz River"]


cowlitz_df.head()
# Out:
#                 Name               Height Capacity (MW) Province/State(s)  \
# 0  Cowlitz Falls Dam   140 ft (43 m)[214]       70[215]        Washington
# 1      Mossyrock Dam  606 ft (185 m)[216]      300[216]        Washington
# 2       Mayfield Dam   250 ft (76 m)[217]      162[217]        Washington
#
#                                          Coordinates Year of completion  \
# 0  46°27′59″N 122°06′33″W﻿ / ﻿46.46639°N 122.10917°W          1994[215]
# 1  46°32′04″N 122°25′29″W﻿ / ﻿46.53444°N 122.42472°W          1968[216]
# 2  46°30′10″N 122°35′18″W﻿ / ﻿46.50278°N 122.58833°W          1963[217]
#
#                                   Owner Reservoir formed         Stream
# 0  Lewis County Public Utility District     Lake Scanewa  Cowlitz River
# 1               Tacoma Public Utilities       Riffe Lake  Cowlitz River
# 2               Tacoma Public Utilities    Lake Mayfield  Cowlitz River

# %%
deschutes_file = ("deschutes.csv")
deschutes_df = pd.read_csv(deschutes_file)

deschutes_df = deschutes_df.drop(['Image'], axis = 1)

deschutes_df["Stream"] = ["Deschutes River", "Deschutes River", "Deschutes River", "Deschutes River", "Deschutes River"]


deschutes_df.head()
# Out:
#                            Name              Height  Capacity (MW)  \
# 0             Crane Prairie Dam   36 ft (11 m)[172]           0.00
# 1                   Wickiup Dam  100 ft (30 m)[172]           0.00
# 2          Round Butte Dam[173]      440 ft (130 m)         247.12
# 3               Pelton Dam[173]       204 ft (62 m)         100.80
# 4  Pelton Reregulating Dam[173]        88 ft (27 m)          18.90
#
#   Province/State(s)                                        Coordinates  \
# 0            Oregon   43°45′18″N 121°47′6″W﻿ / ﻿43.75500°N 121.78500°W
# 1            Oregon  43°41′43″N 121°42′14″W﻿ / ﻿43.69528°N 121.70389°W
# 2            Oregon  44°36′0″N 121°16′12″W﻿ / ﻿44.60000°N 121.27000...
# 3            Oregon  44°41′24″N 121°13′48″W﻿ / ﻿44.69000°N 121.2300...
# 4            Oregon  44°43′12″N 121°14′24″W﻿ / ﻿44.72000°N 121.2400...
#
#   Year of completion                                              Owner  \
# ...

# %%
duncan_file = ("duncan_river.csv")
duncan_df = pd.read_csv(duncan_file)

duncan_df["Stream"] = ["Duncan River"]

duncan_df.head()
# Out:
#               Name         Height  Capacity (MW) Province/State(s)  \
# 0  Duncan Dam[147]  130 ft (40 m)              0  British Columbia
#
#                                         Coordinates  Year of completion  \
# 0  50°15′0″N 116°56′47″W﻿ / ﻿50.25000°N 116.94639°W                1967
#
#       Owner    Reservoir formed  Image        Stream
# 0  BC Hydro  raised Duncan Lake    NaN  Duncan River

# %%
elk_file = ("elk_river.csv")
elk_df = pd.read_csv(elk_file)

elk_df["Stream"] = ["Elk River"]

elk_df.head()
# Out:
#             Name        Height Capacity (MW) Province/State(s)  \
# 0  Elko Dam[145]  52 ft (16 m)       12[146]  British Columbia
#
#                                         Coordinates  Year of completion  \
# 0  49°17′24″N 115°6′16″W﻿ / ﻿49.29000°N 115.10444°W                1924
#
#       Owner Reservoir formed  Image     Stream
# 0  BC Hydro    Elko Dam Pool    NaN  Elk River

# %%
fall_file = ("fall_river.csv")
fall_df = pd.read_csv(fall_file)

fall_df["Stream"] = ["Fall River"]

fall_df.head()
# Out:
#                              Name             Height  Capacity (MW)  \
# 0  Grassy Lake Dam (Grassy Creek)  118 ft (36 m)[32]              0
#
#   Province/State(s)                                        Coordinates  \
# 0           Wyoming  44°07′48″N 110°48′36″W﻿ / ﻿44.13000°N 110.8100...
#
#   Year of completion                                    Owner  \
# 0           1939[93]  United States Bureau of Reclamation[32]
#
#   Reservoir formed       Image      Stream
# 0      Grassy Lake  Fall River  Fall River

# %%
flathead_file = ("flathead_river.csv")
flathead_df = pd.read_csv(flathead_file)

flathead_df["Stream"] = ["Flathead River", "Flathead River"]

flathead_df.head()
# Out:
#                                    Name               Height Capacity (MW)  \
# 0                Hungry Horse Dam[n 22]  564 ft (172 m)[166]      428[167]
# 1  Seli’š Ksanka Qlispe’ Dam (Kerr Dam)   205 ft (62 m)[169]      188[170]
#
#   Province/State(s)                                        Coordinates  \
# 0           Montana  48°20′28″N 114°00′47″W﻿ / ﻿48.34111°N 114.01306°W
# 1           Montana  47°40′38″N 114°14′02″W﻿ / ﻿47.67722°N 114.23389°W
#
#   Year of completion                    Owner  \
# 0          1953[168]                     USBR
# 1          1938[168]  [171]CSKT's EKI: Tribal
#
#                           Reservoir formed  Image          Stream
# 0                   Hungry Horse Reservoir    NaN  Flathead River
# 1  Raised Flathead Lake 10 ft (3.0 m)[168]    NaN  Flathead River

# %%
goose_file = ("goose_creek.csv")
goose_df = pd.read_csv(goose_file)

goose_df["Stream"] = ["Goose Creek"]

goose_df.head()
# Out:
#               Name         Height  Capacity (MW) Province/State(s)  \
# 0  Oakley Dam[106]  139 ft (42 m)              0             Idaho
#
#                                          Coordinates  Year of completion  \
# 0  42°11′24″N 113°54′36″W﻿ / ﻿42.19000°N 113.91000°W                1916
#
#                   Owner             Reservoir formed  Image       Stream
# 0  Oakley Canal Company  Lower Goose Creek Reservoir    NaN  Goose Creek

# %%
henrys_file = ("henrys_fork.csv")
henrys_df = pd.read_csv(henrys_file)

henrys_df["Stream"] = ["Henrys Fork", "Henrys Fork", "Henrys Fork", "Henrys Fork", "Henrys Fork"]

henrys_df.head()
# Out:
#                                        Name             Height Capacity (MW)  \
# 0                           Henrys Lake Dam  18 ft (5.5 m)[86]             0
# 1                           Island Park Dam   94 ft (29 m)[87]       4.8[32]
# 2     Buffalo River Dam (Buffalo River)[88]      12 ft (3.7 m)          0.25
# 3                            Ashton Dam[89]   56.6 ft (17.3 m)          6.85
# 4  Chester Dam (Crosscut Diversion Dam)[91]    14.5 ft (4.4 m)       3.3[92]
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  44°35′24″N 111°21′0″W﻿ / ﻿44.59000°N 111.35000...
# 1             Idaho  44°25′12″N 111°23′24″W﻿ / ﻿44.42000°N 111.3900...
# 2             Idaho  44°24′52″N 111°23′34″W﻿ / ﻿44.41444°N 111.39278°W
# 3             Idaho  44°04′12″N 111°29′24″W﻿ / ﻿44.07000°N 111.4900...
# 4             Idaho   44°0′36″N 111°34′48″W﻿ / ﻿44.01000°N 111.58000°W
#
#   Year of completion                                        Owner  \
# ...

# %%
kachess_file = ("kachess.csv")
kachess_df = pd.read_csv(kachess_file)

kachess_df["Stream"] = ["Kachess River"]

kachess_df.head()
# Out:
#           Name              Height Capacity (MW) Province/State(s)  \
# 0  Kachess Dam  115 ft (35 m)[177]        0[178]        Washington
#
#                                         Coordinates Year of completion Owner  \
# 0  47°15′53″N 121°12′9″W﻿ / ﻿47.26472°N 121.20250°W          1912[177]  USBR
#
#       Reservoir formed  Image         Stream
# 0  Raised Kachess Lake    NaN  Kachess River

# %%
kootenay_file = ("kootenay_river.csv")
kootenay_df = pd.read_csv(kootenay_file)

kootenay_df["Stream"] = ["Kootenay River", "Kootenay River", "Kootenay River", "Kootenay River", "Kootenay River", "Kootenay River", "Kootenay River"]
kootenay_df.head()
# Out:
#                          Name               Height Capacity (MW)  \
# 0                   Libby Dam  420 ft (130 m)[134]      604[135]
# 1              Corra Linn Dam    16 m (52 ft)[137]       51[137]
# 2  Upper Bonnington Falls Dam    21 m (69 ft)[138]         53[8]
# 3  Lower Bonnington Falls Dam    21 m (69 ft)[139]         25[8]
# 4            South Slocan Dam    18 m (59 ft)[140]         57[8]
#
#   Province/State(s)                                        Coordinates  \
# 0           Montana  48°24′37″N 115°18′52″W﻿ / ﻿48.41028°N 115.31444°W
# 1  British Columbia  49°28′04″N 117°28′02″W﻿ / ﻿49.46778°N 117.46722°W
# 2  British Columbia  49°27′35″N 117°29′03″W﻿ / ﻿49.45972°N 117.48417°W
# 3  British Columbia  49°27′39″N 117°29′59″W﻿ / ﻿49.46083°N 117.49972°W
# 4  British Columbia  49°27′20″N 117°31′11″W﻿ / ﻿49.45556°N 117.51972°W
#
#   Year of completion     Owner      Reservoir formed  Image          Stream
# ...

# %%
lewis_file = ("lewis.csv")
lewis_df = pd.read_csv(lewis_file)

lewis_df["Stream"] = ["Lewis River", "Lewis River", "Lewis River", "Lewis River"]

lewis_df.head()
# Out:
#                    Name             Height  Capacity (MW) Province/State(s)  \
# 0        Swift Dam[218]     512 ft (156 m)            240        Washington
# 1  Swift No. 2 Dam[218]  83 ft (25 m)[220]             70        Washington
# 2         Yale Dam[218]      323 ft (98 m)            134        Washington
# 3       Merwin Dam[218]      313 ft (95 m)            136        Washington
#
#                                          Coordinates Year of completion  \
# 0  46°04′48″N 122°12′36″W﻿ / ﻿46.08000°N 122.2100...               1958
# 1  46°03′46″N 122°11′52″W﻿ / ﻿46.06278°N 122.1977...          1959[220]
# 2  45°58′48″N 122°20′24″W﻿ / ﻿45.98000°N 122.3400...               1953
# 3  45°59′24″N 122°28′48″W﻿ / ﻿45.99000°N 122.4800...               1931
#
#                                              Owner Reservoir formed  Image  \
# 0                                       PacifiCorp  Swift Reservoir    NaN
# ...

# %%
little_salmon_file = ("little_salmon.csv")
little_salmon_df = pd.read_csv(little_salmon_file)

little_salmon_df["Stream"] = ["Little Salmon River", "Little Salmon River"]

little_salmon_df.head()
# Out:
#                                              Name         Height  \
# 0                Goose Lake Dam (Goose Creek)[58]  26 ft (7.9 m)
# 1  Brundage Dam (Brundage Creek(Goose Creek))[59]   64 ft (20 m)
#
#    Capacity (MW) Province/State(s)  \
# 0              0             Idaho
# 1              0             Idaho
#
#                                          Coordinates  Year of completion  \
# 0  45°04′13″N 116°10′09″W﻿ / ﻿45.07028°N 116.16917°W                1924
# 1  45°02′30″N 116°07′53″W﻿ / ﻿45.04167°N 116.13139°W                1989
#
#                         Owner    Reservoir formed                Image  \
# 0         Ca Campbell Company          Goose Lake  Little Salmon River
# 1  Brundage Reservoir Company  Brundage Reservoir  Little Salmon River
#
#                 Stream
# 0  Little Salmon River
# 1  Little Salmon River

# %%
little_wood_file = ("little_wood_river.csv")
little_wood_df = pd.read_csv(little_wood_file)

little_wood_df["Stream"] = ["Little Wood River", "Little Wood River"]

little_wood_df.head()
# Out:
#                           Name              Height Capacity (MW)  \
# 0        Little Wood River Dam  169 ft (52 m)[131]        3[132]
# 1  Fish Creek Dam (Fish Creek)   88 ft (27 m)[133]             0
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  43°25′12″N 114°01′12″W﻿ / ﻿43.42000°N 114.0200...
# 1             Idaho  43°25′12″N 114°49′48″W﻿ / ﻿43.42000°N 114.8300...
#
#   Year of completion                                     Owner  \
# 0          1962[131]  United States Bureau of Reclamation[131]
# 1          1923[133]       Carey Valley Reservoir Company[133]
#
#         Reservoir formed  Image             Stream
# 0  Little Wood Reservoir    NaN  Little Wood River
# 1   Fish Creek Reservoir    NaN  Little Wood River

# %%
malad_file = ("malad.csv")
malad_df = pd.read_csv(malad_file)

malad_df["Stream"] = ["Malad River"]

malad_df.head()
# Out:
#                                                 Name  \
# 0  Malad Gorge Dam and Power Flume (Upper and Lower)
#
#                                               Height Capacity (MW)  \
# 0  550 ft (170 m)(Dam) 4,600 ft (1402 m) (Flume) ...     8.27[127]
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  42°51′28″N 114°52′35″W﻿ / ﻿42.85778°N 114.87639°W
#
#   Year of completion                Owner        Reservoir formed  Image  \
# 0     1911/1948[127]  Idaho Power Company  Malad Gorge State Park    NaN
#
#         Stream
# 0  Malad River

# %%
malheaur_file = ("malheaur.csv")
malheaur_df = pd.read_csv(malheaur_file)

malheaur_df["Stream"] = ["Malheur River", "Malheur River", "Malheur River", "Malheur River", "Malheur River", "Malheur River"]

malheaur_df.head()
# Out:
#                                                 Name         Height  \
# 0                           Warm Springs Dam[72][73]  106 ft (32 m)
# 1  Agency Valley Dam (North Fork Malheur River)[7...  110 ft (34 m)
# 2                           Harper Diversion Dam[73]  12 ft (3.7 m)
# 3              Bully Creek Dam (Bully Creek)[73][77]  121 ft (37 m)
# 4        Bully Creek Diversion Dam (Bully Creek)[73]   4 ft (1.2 m)
#
#       Capacity (MW) Province/State(s)  \
# 0  proposed 2.7[74]            Oregon
# 1  proposed 2.0[76]            Oregon
# 2                 0            Oregon
# 3                 0            Oregon
# 4                 0            Oregon
#
#                                          Coordinates  Year of completion  \
# 0  43°35′07″N 118°12′31″W﻿ / ﻿43.58528°N 118.20861°W                1919
# 1  43°54′41″N 118°09′15″W﻿ / ﻿43.91139°N 118.15417°W                1935
# 2  43°49′29″N 117°38′32″W﻿ / ﻿43.82472°N 117.64222°W                1930
# ...

# %%
mark_creek_file = ("mark_creek.csv")
mark_creek_df = pd.read_csv(mark_creek_file)

mark_creek_df["Stream"] = ["Mark Creek"]

mark_creek_df.head()
# Out:
#                         Name          Height  Capacity (MW) Province/State(s)  \
# 0  Upper Mark Creek Dam[148]  21.5 m (71 ft)              0  British Columbia
#
#                                         Coordinates  Year of completion  \
# 0  49°42′36″N 116°2′33″W﻿ / ﻿49.71000°N 116.04250°W                1994
#
#                Owner          Reservoir formed  Image      Stream
# 0  City of Kimberley  Mark Creek Dam Reservoir    NaN  Mark Creek

# %%
mckenzie_file = ("mckenzie.csv")
mckenzie_df = pd.read_csv(mckenzie_file)

mckenzie_df["Stream"] = ["McKenzie River", "McKenzie River", "McKenzie River", "McKenzie River", "McKenzie River", "McKenzie River", "McKenzie River"]

mckenzie_df.head()
# Out:
#                                Name              Height Capacity (MW)  \
# 0              Carmen Diversion Dam  17 ft (5.2 m)[194]        0[195]
# 1                  Trail Bridge Dam   90 ft (27 m)[197]       10[195]
# 2           Smith Dam (Smith River)  250 ft (76 m)[198]    104.5[195]
# 3      Cougar Dam (South Fork)[199]      425 ft (130 m)            25
# 4  Blue River Dam (Blue River)[199]       270 ft (82 m)             0
#
#   Province/State(s)                                        Coordinates  \
# 0            Oregon  44°20′19″N 122°00′11″W﻿ / ﻿44.33861°N 122.00306°W
# 1            Oregon  44°16′24″N 122°03′02″W﻿ / ﻿44.27333°N 122.05056°W
# 2            Oregon  44°0′0″N 122°06′36″W﻿ / ﻿44.00000°N 122.11000°...
# 3            Oregon  44°07′44″N 122°14′30″W﻿ / ﻿44.12889°N 122.24167°W
# 4            Oregon  44°10′23″N 122°19′47″W﻿ / ﻿44.17306°N 122.32972°W
#
#   Year of completion                          Owner        Reservoir formed  \
# ...

# %%
middle_fork_willamette_file = ("middle_fork_willamette.csv")
middle_fork_willamette_df = pd.read_csv(middle_fork_willamette_file)

middle_fork_willamette_df["Stream"] = ["Middle Fork Willamette River", "Middle Fork Willamette River", "Middle Fork Willamette River", "Middle Fork Willamette River"]

middle_fork_willamette_df.head()
# Out:
#                   Name              Height Capacity (MW) Province/State(s)  \
# 0      Hills Creek Dam  304 ft (93 m)[191]       30[191]            Oregon
# 1    Lookout Point Dam  276 ft (84 m)[192]      150[192]            Oregon
# 2  Fall Creek Dam[193]       180 ft (55 m)             0            Oregon
# 3           Dexter Dam   93 ft (28 m)[192]       15[192]            Oregon
#
#                                          Coordinates Year of completion  \
# 0  43°42′33″N 122°25′26″W﻿ / ﻿43.70917°N 122.42389°W          1961[191]
# 1  43°54′48″N 122°45′09″W﻿ / ﻿43.91333°N 122.75250°W          1954[192]
# 2  43°54′49″N 122°45′25″W﻿ / ﻿43.91361°N 122.75694°W               1966
# 3  43°55′22″N 122°48′23″W﻿ / ﻿43.92278°N 122.80639°W          1954[192]
#
#    Owner       Reservoir formed  Image                        Stream
# 0  USACE  Hills Creek Reservoir    NaN  Middle Fork Willamette River
# 1  USACE     Lookout Point Lake    NaN  Middle Fork Willamette River
# ...

# %%
north_fork_clearwater_file = ("north_fork_clearwater_river.csv")
north_fork_clearwater_df = pd.read_csv(north_fork_clearwater_file)

north_fork_clearwater_df["Stream"] = ["North Fork Clearwater River"]

north_fork_clearwater_df.head()
# Out:
#            Name               Height  Capacity (MW) Province/State(s)  \
# 0  Dworshak Dam  717 ft (219 m)[126]            400             Idaho
#
#                                Coordinates  Year of completion  \
# 0  46°30′N 116°18′W﻿ / ﻿46.500°N 116.300°W                1973
#
#                      Owner    Reservoir formed  Image  \
# 0  Army Corps of Engineers  Dworshak Reservoir    NaN
#
#                         Stream
# 0  North Fork Clearwater River

# %%
north_payette_file = ("north_fork_payette.csv")
north_payette_df = pd.read_csv(north_payette_file)

north_payette_df["Stream"] = ["North Fork Payette River", "North Fork Payette River", "North Fork Payette River", "North Fork Payette River", "North Fork Payette River", "North Fork Payette River", "North Fork Payette River"]

north_payette_df.head()
# Out:
#                                        Name           Height Capacity (MW)  \
# 0               Upper Payette Lake Dam[118]    18 ft (5.5 m)             0
# 1      Granite Lake Dam (Fisher Creek)[119]    28 ft (8.5 m)             0
# 2                     Payette Lake Dam[120]   8.2 ft (2.5 m)             0
# 3  Little Payette Lake Dam (Lake Fork)[121]  15.8 ft (4.8 m)             0
# 4                          Cascade Dam[122]    107 ft (33 m)      12.8[98]
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  45°06′40″N 116°01′35″W﻿ / ﻿45.11111°N 116.02639°W
# 1             Idaho  45°06′02″N 116°04′51″W﻿ / ﻿45.10056°N 116.08083°W
# 2             Idaho  44°54′36″N 116°06′36″W﻿ / ﻿44.91000°N 116.11000°W
# 3             Idaho   44°54′0″N 116°02′24″W﻿ / ﻿44.90000°N 116.04000°W
# 4             Idaho   44°31′12″N 116°03′0″W﻿ / ﻿44.52000°N 116.05000°W
#
#    Year of completion                                Owner  \
# ...

# %%
owyhee_file = ("owyhee.csv")
owyhee_df = pd.read_csv(owyhee_file)

owyhee_df["Stream"] = ["Owyhee River", "Owyhee River", "Owyhee River"]

owyhee_df.head()
# Out:
#                                                 Name                 Height  \
# 0                                     Wild Horse Dam  114 ft (35 m)[60][61]
# 1  Antelope Reservoir Dam (Antelope Creek (Jordan...           60 ft (18 m)
# 2                                         Owyhee Dam     417 ft (127 m)[65]
#
#              Capacity (MW) Province/State(s)  \
# 0                        0            Nevada
# 1                        0            Oregon
# 2  5[n 14],8[n 15],2[n 16]            Oregon
#
#                                          Coordinates Year of completion  \
# 0  41°41′14″N 115°50′43″W﻿ / ﻿41.68722°N 115.84528°W  1937 / 1969[n 13]
# 1   42°54′0″N 117°13′48″W﻿ / ﻿42.90000°N 117.23000°W               1923
# 2  43°38′31″N 117°14′33″W﻿ / ﻿43.64194°N 117.24250°W           1932[65]
#
#                                Owner      Reservoir formed         Image  \
# 0                            BIA[63]  Wild Horse Reservoir  Owyhee River
# ...

# %%
payette_file = ("payette.csv")
payette_df = pd.read_csv(payette_file)

payette_df["Stream"] = ["Payette River"]

payette_df.head()
# Out:
#                               Name         Height Capacity (MW)  \
# 0  Black Canyon Diversion Dam[117]  183 ft (56 m)      10.2[98]
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  43°52′48″N 116°28′48″W﻿ / ﻿43.88000°N 116.48000°W
#
#    Year of completion                                Owner  \
# 0                1924  United States Bureau of Reclamation
#
#          Reservoir formed  Image         Stream
# 0  Black Canyon Reservoir    NaN  Payette River

# %%
pend_file = ("pend_oreille_river.csv")
pend_df = pd.read_csv(pend_file)

pend_df["Stream"] = ["Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River", "Pend Oreille River/Clark Fork River"]

pend_df.head()
# Out:
#                  Name                    Height Capacity (MW)  \
# 0          Clark Fork                Clark Fork    Clark Fork
# 1  Thompson Falls Dam  110 ft (34 m)[149][n 20]       94[153]
# 2    Noxon Rapids Dam        260 ft (79 m)[154]      527[155]
# 3   Cabinet Gorge Dam        208 ft (63 m)[157]      255[158]
# 4        Pend Oreille              Pend Oreille  Pend Oreille
#
#   Province/State(s)                                        Coordinates  \
# 0        Clark Fork                                         Clark Fork
# 1           Montana  47°35′28″N 115°21′03″W﻿ / ﻿47.59111°N 115.35083°W
# 2           Montana  47°57′39″N 115°44′01″W﻿ / ﻿47.96083°N 115.73361°W
# 3             Idaho  48°05′08″N 116°03′27″W﻿ / ﻿48.08556°N 116.05750°W
# 4      Pend Oreille                                       Pend Oreille
#
#   Year of completion                Owner          Reservoir formed  \
# 0         Clark Fork           Clark Fork                Clark Fork
# ...

# %%
portneuf_file = ("portneuf_river.csv")
portneuf_df = pd.read_csv(portneuf_file)

portneuf_df["Stream"] = ["Portneuf River"]

portneuf_df.head()
# Out:
#                Name        Height  Capacity (MW) Province/State(s)  \
# 0  Portneuf Dam[94]  47 ft (14 m)              0             Idaho
#
#                                          Coordinates  Year of completion  \
# 0  42°52′12″N 111°56′24″W﻿ / ﻿42.87000°N 111.94000°W                1912
#
#                                  Owner        Reservoir formed          Stream
# 0  Portneuf-Marsh Valley Canal Company  Chesterfield Reservoir  Portneuf River

# %%
powder_file = ("powder_river.csv")
powder_df = pd.read_csv(powder_file)

powder_df["Stream"] = ["Powder River", "Powder River"]

powder_df.head()
# Out:
#                        Name         Height     Capacity (MW)  \
# 0         Mason Dam[80][81]  173 ft (53 m)  proposed 3.4[82]
# 1  Thief Valley Dam[81][83]   73 ft (22 m)                 0
#
#   Province/State(s)                                        Coordinates  \
# 0            Oregon  44°40′12″N 117°59′24″W﻿ / ﻿44.67000°N 117.99000°W
# 1            Oregon   45°0′36″N 117°46′12″W﻿ / ﻿45.01000°N 117.77000°W
#
#    Year of completion                                Owner  \
# 0                1968  United States Bureau of Reclamation
# 1                1932  United States Bureau of Reclamation
#
#          Reservoir formed         Image        Stream
# 0            Philips Lake  Powder River  Powder River
# 1  Thief Valley Reservoir  Powder River  Powder River

# %%
salmon_falls_file = ("salmon_falls_creek.csv")
salmon_falls_df = pd.read_csv(salmon_falls_file)

salmon_falls_df["Stream"] = ["Salmon Falls Creek", "Salmon Falls Creek"]

salmon_falls_df.head()
# Out:
#                                 Name         Height  Capacity (MW)  \
# 0               Salmon Falls Dam[95]  217 ft (66 m)              0
# 1  Cedar Creek Dam (Cedar Creek)[96]   84 ft (26 m)              0
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  42°12′36″N 114°43′48″W﻿ / ﻿42.21000°N 114.73000°W
# 1             Idaho  42°13′12″N 114°52′12″W﻿ / ﻿42.22000°N 114.87000°W
#
#    Year of completion                                   Owner  \
# 0                1911        Salmon River Canal Company, Ltd.
# 1                1920  Cedar Mesa Reservoir And Canal Company
#
#                Reservoir formed  Image              Stream
# 0  Salmon Falls Creek Reservoir    NaN  Salmon Falls Creek
# 1         Cedar Creek Reservoir    NaN  Salmon Falls Creek

# %%
santiam_file = ("santiam.csv")
santiam_df = pd.read_csv(santiam_file)

santiam_df["Stream"] = ["Santiam River", "Santiam River", "Santiam River", "Santiam River"]

santiam_df.head()
# Out:
#                                    Name          Height  Capacity (MW)  \
# 0    Big Cliff Dam (North Santiam)[189]   191 ft (58 m)             18
# 1        Detroit Dam(North Santiam[189]  463 ft (141 m)            100
# 2       Foster Dam (South Santiam)[190]   126 ft (38 m)             20
# 3  Green Peter Dam (South Santiam)[190]  327 ft (100 m)             80
#
#   Province/State(s)                                        Coordinates  \
# 0            Oregon  44°45′03″N 122°16′59″W﻿ / ﻿44.75083°N 122.28306°W
# 1            Oregon  44°43′18″N 122°15′01″W﻿ / ﻿44.72167°N 122.25028°W
# 2            Oregon  44°24′55″N 122°40′13″W﻿ / ﻿44.41528°N 122.67028°W
# 3            Oregon  44°27′00″N 122°32′57″W﻿ / ﻿44.45000°N 122.54917°W
#
#    Year of completion                    Owner  \
# 0                1953  Army Corps of Engineers
# 1                1953  Army Corps of Engineers
# 2                1968  Army Corps of Engineers
# 3                1968  Army Corps of Engineers
#
# ...

# %%
snake_file = ("snake_river.csv")
snake_df = pd.read_csv(snake_file)

snake_df.head(10)
# Out:
#                      Name                Height Capacity (MW)  \
# 0        Jackson Lake Dam  65.5 ft (20.0 m)[28]             0
# 1           Palisades Dam     270 ft (82 m)[29]     176.6[29]
# 2           Gem State Dam          40 ft (12 m)      22.6[30]
# 3      American Falls Dam     104 ft (32 m)[31]     112.4[32]
# 4            Minidoka Dam      86 ft (26 m)[33]      28.5[33]
# 5              Milner Dam      38 ft (12 m)[34]      59.5[35]
# 6          Twin Falls Dam    25 ft (7.6 m)[n 5]      52.9[36]
# 7      Shoshone Falls Dam     16 ft (4.9 m)[37]        64[38]
# 8  Upper Salmon Falls Dam    18 ft (5.5 m)[n 5]      34.5[35]
# 9  Lower Salmon Falls Dam      38 ft (12 m)[39]        60[35]
#
#   Province/State(s)                                        Coordinates  \
# 0           Wyoming  43°51′30″N 110°35′24″W﻿ / ﻿43.85833°N 110.59000°W
# 1             Idaho  43°19′59″N 111°12′12″W﻿ / ﻿43.33306°N 111.20333°W
# ...

# %%
south_fork_boise_file = ("south_fork_boise.csv")
south_fork_boise_df = pd.read_csv(south_fork_boise_file)

south_fork_boise_df["Stream"] = ["South Fork Boise River", "South Fork Boise River"]

south_fork_boise_df.head()
# Out:
#                                          Name          Height Capacity (MW)  \
# 0                     Anderson Ranch Dam[104]  456 ft (139 m)        40[98]
# 1  Little Camas Dam (Little Camas Creek)[105]    44 ft (13 m)             0
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  43°21′36″N 115°26′24″W﻿ / ﻿43.36000°N 115.44000°W
# 1             Idaho   43°21′0″N 115°22′48″W﻿ / ﻿43.35000°N 115.38000°W
#
#    Year of completion                                Owner  \
# 0                1947  United States Bureau of Reclamation
# 1                1912    Mountain Home Irrigation District
#
#            Reservoir formed  Image                  Stream
# 0  Anderson Ranch Reservoir    NaN  South Fork Boise River
# 1    Little Camas Reservoir    NaN  South Fork Boise River

# %%
south_fork_owyhee_file = ("south_fork_owyhee.csv")
south_fork_owyhee_df = pd.read_csv(south_fork_owyhee_file)

south_fork_owyhee_df["Stream"] = ["South Fork Owyhee River", "South Fork Owyhee River", "South Fork Owyhee River", "South Fork Owyhee River", "South Fork Owyhee River", "South Fork Owyhee River"]

south_fork_owyhee_df.head()
# Out:
#                                        Name         Height  Capacity (MW)  \
# 0   Wilson Reservoir Dam (Wilson Creek)[66]   34 ft (10 m)              0
# 1         Bull Run Dam (Bull Run Creek)[67]   69 ft (21 m)              0
# 2          Dry Creek Dam (Indian Creek)[68]   70 ft (21 m)              0
# 3  Rawhide Reservoir Dam (Indian Creek)[69]   33 ft (10 m)              0
# 4         Sheep Creek Dam (Sheep Creek)[70]  29 ft (8.8 m)              0
#
#   Province/State(s)                                        Coordinates  \
# 0            Nevada  41°40′12″N 116°20′24″W﻿ / ﻿41.67000°N 116.34000°W
# 1            Nevada   41°38′24″N 116°09′0″W﻿ / ﻿41.64000°N 116.15000°W
# 2            Nevada  41°47′24″N 116°13′48″W﻿ / ﻿41.79000°N 116.23000°W
# 3            Nevada  41°42′36″N 116°20′24″W﻿ / ﻿41.71000°N 116.34000°W
# 4            Nevada  41°51′36″N 116°16′12″W﻿ / ﻿41.86000°N 116.27000°W
#
#    Year of completion                                              Owner  \
# ...

# %%
south_fork_payette_file = ("south_fork_payette.csv")
south_fork_payette_df = pd.read_csv(south_fork_payette_file)

south_fork_payette_df["Stream"] = ["South Fork Payette River"]

south_fork_payette_df.head()
# Out:
#                                  Name         Height Capacity (MW)  \
# 0  Deadwood Dam (Deadwood River)[125]  183 ft (56 m)         0[98]
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  44°17′24″N 115°38′24″W﻿ / ﻿44.29000°N 115.64000°W
#
#    Year of completion                                Owner  \
# 0                1931  United States Bureau of Reclamation
#
#      Reservoir formed  Image                    Stream
# 0  Deadwood Reservoir    NaN  South Fork Payette River

# %%
spillimacheen_file = ("spillimacheen.csv")
spillimacheen_df = pd.read_csv(spillimacheen_file)

spillimacheen_df["Stream"] = ["Spillimacheen River"]

spillimacheen_df.head()
# Out:
#                      Name          Height  Capacity (MW) Province/State(s)  \
# 0  Spillimacheen Dam[223]  14.5 m (48 ft)              4  British Columbia
#
#                                          Coordinates Year of completion  \
# 0  50°53′56″N 116°25′28″W﻿ / ﻿50.89889°N 116.42444°W          1955[224]
#
#       Owner        Reservoir formed  Image               Stream
# 0  BC Hydro  Spillimacheen Dam Pool    NaN  Spillimacheen River

# %%
spokane_file = ("spokane.csv")
spokane_df = pd.read_csv(spokane_file)

spokane_df["Stream"] = ["Spokane River", "Spokane River", "Spokane River", "Spokane River", "Spokane River", "Spokane River", "Spokane River"]

spokane_df.head()
# Out:
#                                    Name              Height Capacity (MW)  \
# 0  Post Falls Hydroelectric Development   64 ft (20 m)[205]       15[205]
# 1                           Upriver Dam                 NaN     17.7[206]
# 2                       Upper Falls Dam   35 ft (11 m)[207]       10[207]
# 3                     Monroe Street Dam  24 ft (7.3 m)[208]       15[208]
# 4                         Nine Mile Dam   58 ft (18 m)[209]       26[209]
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  47°42′31″N 116°57′13″W﻿ / ﻿47.70861°N 116.95361°W
# 1        Washington  47°41′09″N 117°19′43″W﻿ / ﻿47.68583°N 117.32861°W
# 2        Washington  47°39′46″N 117°24′55″W﻿ / ﻿47.66278°N 117.41528°W
# 3        Washington  47°39′42″N 117°25′31″W﻿ / ﻿47.66167°N 117.42528°W
# 4        Washington  47°46′30″N 117°32′38″W﻿ / ﻿47.77500°N 117.54389°W
#
#   Year of completion            Owner           Reservoir formed  Image  \
# ...

# %%
tieton_file = ("tieton.csv")
tieton_df = pd.read_csv(tieton_file)

tieton_df["Stream"] = ["Tieton River", "Tieton River"]

tieton_df.head()
# Out:
#                                   Name              Height Capacity (MW)  \
# 0  Clear Creek Dam (North Fork Tieton)   83 ft (25 m)[177]        0[178]
# 1                           Tieton Dam  319 ft (97 m)[177]        0[178]
#
#   Province/State(s)                                        Coordinates  \
# 0        Washington  46°37′40″N 121°16′15″W﻿ / ﻿46.62778°N 121.27083°W
# 1        Washington   46°39′26″N 121°7′41″W﻿ / ﻿46.65722°N 121.12806°W
#
#   Year of completion Owner Reservoir formed  Image        Stream
# 0          1915[177]  USBR       Clear Lake    NaN  Tieton River
# 1          1925[177]  USBR     Rimrock Lake    NaN  Tieton River

# %%
wallowa_file = ("wallowa.csv")
wallowa_df = pd.read_csv(wallowa_file)

wallowa_df["Stream"] = ["Wallowa River"]

wallowa_df.head()
# Out:
#                    Name        Height  Capacity (MW) Province/State(s)  \
# 0  Wallowa Lake Dam[79]  40 ft (12 m)              0            Oregon
#
#                                          Coordinates  Year of completion  \
# 0  45°19′48″N 117°13′12″W﻿ / ﻿45.33000°N 117.22000°W                1931
#
#                         Owner     Reservoir formed          Image  \
# 0  Associated Ditch Companies  Raised Wallowa Lake  Wallowa River
#
#           Stream
# 0  Wallowa River

# %%
weiser_file = ("weiser_river.csv")
weiser_df = pd.read_csv(weiser_file)

weiser_df["Stream"] = ["Weiser River", "Weiser River", "Weiser River", "Weiser River"]

weiser_df.head()
# Out:
#                                                 Name         Height  \
# 0  Lost Valley Dam (Lost Creek(West Fork Weiser R...   52 ft (16 m)
# 1          C Ben Ross Dam (Little Weiser River)[108]   56 ft (17 m)
# 2                 Crane Creek Dam (Crane Creek)[109]   55 ft (17 m)
# 3                   Mann Creek Dam (Mann Creek)[110]  148 ft (45 m)
#
#   Capacity (MW) Province/State(s)  \
# 0             0             Idaho
# 1             0             Idaho
# 2             0             Idaho
# 3        0[111]             Idaho
#
#                                          Coordinates  Year of completion  \
# 0  44°57′23″N 116°28′02″W﻿ / ﻿44.95639°N 116.46722°W                1929
# 1  44°31′12″N 116°26′24″W﻿ / ﻿44.52000°N 116.44000°W                1937
# 2   44°21′0″N 116°36′36″W﻿ / ﻿44.35000°N 116.61000°W                1912
# 3  44°23′24″N 116°53′24″W﻿ / ﻿44.39000°N 116.89000°W                1967
#
# ...

# %%
wenatchee_file = ("wenatchee.csv")
wenatchee_df = pd.read_csv(wenatchee_file)

wenatchee_df["Stream"] = ["Wenatchee River"]

wenatchee_df.head()
# Out:
#                        Name         Height  Capacity (MW) Province/State(s)  \
# 0  Tumwater Canyon Dam[225]  23 ft (7.0 m)              0        Washington
#
#                                          Coordinates  Year of completion  \
# 0  47°36′59″N 120°43′22″W﻿ / ﻿47.61639°N 120.72278°W                1909
#
#                                    Owner Reservoir formed  Image  \
# 0  Chelan County Public Utility District     Lake Jolanda    NaN
#
#             Stream
# 0  Wenatchee River

# %%
willamette_file = ("willamette.csv")
willamette_df = pd.read_csv(willamette_file)

willamette_df["Stream"] = ["Willamette River"]

willamette_df.head()
# Out:
#                    Name              Height Capacity (MW) Province/State(s)  \
# 0  Willamette Falls Dam  20 ft (6.1 m)[187]    15.18[188]            Oregon
#
#                                          Coordinates Year of completion  \
# 0  45°21′11″N 122°37′04″W﻿ / ﻿45.35306°N 122.61778°W           1888[18]
#
#                        Owner  Reservoir formed  Image            Stream
# 0  Portland General Electric               NaN    NaN  Willamette River

# %%
willow_creek_file = ("willow_creek.csv")
willow_creek_df = pd.read_csv(willow_creek_file)

willow_creek_df["Stream"] = ["Willow Creek"]

willow_creek_df.head()
# Out:
#         Name              Height  Capacity (MW) Province/State(s)  \
# 0  Ririe Dam  253 ft (77 m)[115]              0             Idaho
#
#                                          Coordinates Year of completion  \
# 0  43°34′48″N 111°44′24″W﻿ / ﻿43.58000°N 111.7400...          1977[116]
#
#                                       Owner Reservoir formed  Image  \
# 0  United States Bureau of Reclamation[116]  Ririe Reservoir    NaN
#
#          Stream
# 0  Willow Creek

# %%
yakima_file = ("yakima.csv")
yakima_df = pd.read_csv(yakima_file)

yakima_df["Stream"] = ["Yakima River", "Yakima River", "Yakima River", "Yakima River", "Yakima River", "Yakima River", "Yakima River", "Yakima River"]

yakima_df.head()
# Out:
#                     Name              Height Capacity (MW) Province/State(s)  \
# 0          Keechelus Dam  128 ft (39 m)[177]        0[178]        Washington
# 1   Easton Diversion Dam   66 ft (20 m)[179]        0[178]        Washington
# 2  Unnamed Diversion Dam                 NaN             0        Washington
# 3     Roza Diversion Dam   67 ft (20 m)[181]            12        Washington
# 4             Wapato Dam  19 ft (5.8 m)[183]             0        Washington
#
#                                          Coordinates Year of completion Owner  \
# 0  47°19′20″N 121°20′22″W﻿ / ﻿47.32222°N 121.33944°W          1917[177]  USBR
# 1  47°14′30″N 121°11′17″W﻿ / ﻿47.24167°N 121.18806°W          1929[180]  USBR
# 2  47°03′50″N 120°39′09″W﻿ / ﻿47.06389°N 120.65250°W                NaN  USBR
# 3  46°44′56″N 120°27′56″W﻿ / ﻿46.74889°N 120.46556°W          1939[182]  USBR
# 4  46°31′27″N 120°28′37″W﻿ / ﻿46.52417°N 120.47694°W                NaN   NaN
#
# ...

# %%
frames = [
  big_wood_river_df,
    blackfoot_river_df,
    boise_df,
    bull_df,
    burnt_df,
    bumping_df,
    camas_df,
    chelan_df,
    cle_elum_df,
    coast_fork_willamette_df,
    columbia_river_main_df,
    cowlitz_df,
    deschutes_df,
    duncan_df,
    elk_df,
    fall_df,
    flathead_df,
    goose_df,
    henrys_df,
    kachess_df,
    kootenay_df,
    lewis_df,
    little_salmon_df,
    little_wood_df,
    malad_df,
    malheaur_df,
    mark_creek_df,
    mckenzie_df,
    middle_fork_willamette_df,
    north_payette_df,
    owyhee_df,
    payette_df,
    pend_df,
    portneuf_df,
    salmon_falls_df,
    santiam_df,
    south_fork_boise_df,
    south_fork_owyhee_df,
    south_fork_payette_df,
    spillimacheen_df,
    spokane_df,
    tieton_df,
    wallowa_df,
    weiser_df,
    wenatchee_df,
    willamette_df,
    willow_creek_df,
    yakima_df,
    north_fork_clearwater_df,
    powder_df,
    snake_df]
dams_df = pd.concat(frames)
dams_df = dams_df.drop(['Image'], axis = 1)
dams_df.tail()
# Out:
#                     Name              Height Capacity (MW)  \
# 15      Hells Canyon Dam  330 ft (100 m)[47]       450[48]
# 16     Lower Granite Dam   181 ft (55 m)[49]       932[50]
# 17      Little Goose Dam   253 ft (77 m)[52]       932[53]
# 18  Lower Monumental Dam   152 ft (46 m)[54]       930[55]
# 19        Ice Harbor Dam   213 ft (65 m)[56]       693[57]
#
#           Province/State(s)  \
# 15  Idaho /   Oregon border
# 16               Washington
# 17               Washington
# 18               Washington
# 19               Washington
#
#                                           Coordinates  Year of completion  \
# 15  45°14′34″N 116°42′05″W﻿ / ﻿45.24278°N 116.70139°W                1967
# 16  46°39′40″N 117°25′41″W﻿ / ﻿46.66111°N 117.42806°W  1975 / 1987 [n 11]
# 17  46°35′13″N 118°01′40″W﻿ / ﻿46.58694°N 118.02778°W                1970
# 18  46°33′48″N 118°32′20″W﻿ / ﻿46.56333°N 118.53889°W                1969
# ...

# %%
dams_df = dams_df.drop(['Owner'], axis = 1)
dams_df = dams_df.drop(['Reservoir formed'], axis = 1)

dams_df.head()
# Out:
#                              Name              Height Capacity (MW)  \
# 0                       Magic Dam  128 ft (39 m)[128]        9[129]
# 0                   Blackfoot Dam    44 ft (13 m)[84]             0
# 0               Arrowrock Dam[97]      350 ft (110 m)        15[98]
# 1              Lucky Peak Dam[99]      340 ft (100 m)   101.25[100]
# 2  Boise River Diversion Dam[101]        68 ft (21 m)       3.3[98]
#
#   Province/State(s)                                        Coordinates  \
# 0             Idaho  43°15′0″N 114°22′12″W﻿ / ﻿43.25000°N 114.37000...
# 0             Idaho  43°0′0″N 111°42′36″W﻿ / ﻿43.00000°N 111.71000°...
# 0             Idaho   43°36′0″N 115°55′12″W﻿ / ﻿43.60000°N 115.92000°W
# 1             Idaho   43°31′12″N 116°03′0″W﻿ / ﻿43.52000°N 116.05000°W
# 2             Idaho  43°31′48″N 116°05′24″W﻿ / ﻿43.53000°N 116.09000°W
#
#   Year of completion           Stream
# 0          1910[128]   Big Wood River
# 0           1911[85]  Blackfoot River
# ...

# %%
dams_df.dtypes
# Out:
# Name                  object
# Height                object
# Capacity (MW)         object
# Province/State(s)     object
# Coordinates           object
# Year of completion    object
# Stream                object
# dtype: object

# %%
dams_df.convert_dtypes(infer_objects=False).dtypes
# Out:
# Name                  string
# Height                string
# Capacity (MW)         object
# Province/State(s)     string
# Coordinates           string
# Year of completion    object
# Stream                string
# dtype: object

# %%
dams_df.to_excel("dams_data.xlsx")
