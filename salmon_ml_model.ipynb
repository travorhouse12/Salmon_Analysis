# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# pgAdmnin interface

# %%
# Pull in Data
df = pd.read_csv('Data/salmon_preprocessed.csv')
df.head()
# Out:
#    Brood_Year                                Nwr_Population_Name  \
# 0        1977  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 1        1978  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 2        1979  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 3        1980  Chinook Salmon (Snake River Fall-run ESU) - Sn...
# 4        1981  Chinook Salmon (Snake River Fall-run ESU) - Sn...
#
#    Number_Of_Spawners  Start_Year  End_Year  Effective_Catch  Fracwild  \
# 0               600.0      1975.0    2008.0           1097.0       1.0
# 1               640.0      1975.0    2008.0           1011.0       1.0
# 2               500.0      1975.0    2008.0            514.0       1.0
# 3               450.0      1975.0    2008.0            159.0       1.0
# 4               340.0      1975.0    2008.0            150.0       1.0
#
#    Spawners_Prev_Yr  Eff_Catch_Prev_Yr  Fracwild_Prev_Yr  \
# 0             470.0                1.0               1.0
# 1             600.0                1.0               1.0
# 2             640.0                1.0               1.0
# 3             500.0                1.0               1.0
# 4             450.0                1.0               1.0
#
#    Spawners_Two_Yrs_Prior  Eff_Catch_Two_Yrs_Prior  Fracwild_Two_Yrs_Prior
# 0                  1000.0                      1.0                     1.0
# 1                   470.0                      1.0                     1.0
# 2                   600.0                      1.0                     1.0
# 3                   640.0                      1.0                     1.0
# 4                   500.0                      1.0                     1.0

# %%
# Isolate the Stream we want to teach the model on and reset index
target_df = df.loc[df['Nwr_Population_Name'] == 'Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal']
target_df.reset_index(drop=True, inplace=True)
target_df.head()
# Out:
#    Brood_Year                                Nwr_Population_Name  \
# 0        1970  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 1        1971  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 2        1972  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 3        1973  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 4        1974  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
#
#    Number_Of_Spawners  Start_Year  End_Year  Effective_Catch  Fracwild  \
# 0              1157.0         NaN       NaN           7187.0      0.79
# 1              1340.0         NaN       NaN           8467.0      0.73
# 2               551.0         NaN       NaN           2779.0      0.77
# 3               913.0         NaN       NaN           6988.0      0.77
# 4               347.0         NaN       NaN           1278.0      0.77
#
#    Spawners_Prev_Yr  Eff_Catch_Prev_Yr  Fracwild_Prev_Yr  \
# 0            6664.0               0.96              0.96
# 1            1157.0               0.79              0.79
# 2            1340.0               0.73              0.73
# 3             551.0               0.77              0.77
# 4             913.0               0.77              0.77
#
#    Spawners_Two_Yrs_Prior  Eff_Catch_Two_Yrs_Prior  Fracwild_Two_Yrs_Prior
# 0                  5290.0                     0.93                    0.93
# 1                  6664.0                     0.96                    0.96
# 2                  1157.0                     0.79                    0.79
# 3                  1340.0                     0.73                    0.73
# 4                   551.0                     0.77                    0.77

# %%
# Delete first two rows and reset index
target_df = target_df.drop(target_df.index[[0,1]])
target_df.reset_index(drop=True, inplace=True)
target_df
# Out:
#     Brood_Year                                Nwr_Population_Name  \
# 0         1972  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 1         1973  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 2         1974  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 3         1975  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 4         1976  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 5         1977  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 6         1978  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 7         1979  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 8         1980  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 9         1981  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 10        1982  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 11        1983  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 12        1984  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 13        1985  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 14        1986  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 15        1987  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 16        1988  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 17        1989  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 18        1990  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 19        1991  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 20        1992  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 21        1993  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 22        1994  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 23        1995  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 24        1996  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 25        1997  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 26        1998  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 27        1999  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 28        2000  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 29        2001  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 30        2002  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 31        2003  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 32        2004  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 33        2005  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 34        2006  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 35        2007  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 36        2008  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 37        2009  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 38        2010  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
#
#     Number_Of_Spawners  Start_Year  End_Year  Effective_Catch  Fracwild  \
# 0                551.0         NaN       NaN           2779.0      0.77
# 1                913.0         NaN       NaN           6988.0      0.77
# 2                347.0         NaN       NaN           1278.0      0.77
# 3                954.0         NaN       NaN           4596.0      0.78
# 4                347.0         NaN       NaN           1144.0      0.49
# 5                735.0         NaN       NaN           5176.0      0.67
# 6                 56.0         NaN       NaN            519.0      0.53
# 7                676.0         NaN       NaN          11906.0      0.71
# 8                245.0         NaN       NaN           3627.0      0.72
# 9                175.0         NaN       NaN           2524.0      0.89
# 10               135.0         NaN       NaN            691.0      0.73
# 11               602.0         NaN       NaN          12235.0      0.73
# 12               712.0         NaN       NaN           7644.0      0.74
# 13              1553.0         NaN       NaN           9839.0      0.75
# 14                45.0         NaN       NaN            477.0      0.70
# 15               111.0         NaN       NaN            413.0      0.88
# 16               128.0         NaN       NaN            492.0      0.72
# 17               118.0         NaN       NaN           1750.0      0.88
# 18                57.0         NaN       NaN            567.0      0.60
# 19                87.0         NaN       NaN            604.0      0.82
# 20               123.0         NaN       NaN           1391.0      0.73
# 21               122.0         NaN       NaN           1050.0      0.88
# 22               385.0         NaN       NaN           1061.0      0.90
# 23               119.0         NaN       NaN            122.0      0.89
# 24                40.0         NaN       NaN             14.0      0.87
# 25               211.0         NaN       NaN            155.0      0.91
# 26               306.0         NaN       NaN             73.0      0.75
# 27               936.0         NaN       NaN            378.0      0.79
# 28               445.0         NaN       NaN            602.0      0.66
# 29               343.0         NaN       NaN            443.0      0.70
# 30               107.0         NaN       NaN            425.0      0.88
# 31               199.0         NaN       NaN            186.0      0.82
# 32               133.0         NaN       NaN             88.0      0.87
# 33                46.0         NaN       NaN             30.0      0.98
# 34                41.0         NaN       NaN             24.0      0.85
# 35                76.0         NaN       NaN             52.0      0.59
# 36               278.0         NaN       NaN            102.0      0.40
# 37               157.0         NaN       NaN             21.0      0.23
# 38                83.0         NaN       NaN             10.0      0.37
#
#     Spawners_Prev_Yr  Eff_Catch_Prev_Yr  Fracwild_Prev_Yr  \
# 0             1340.0               0.73              0.73
# 1              551.0               0.77              0.77
# 2              913.0               0.77              0.77
# 3              347.0               0.77              0.77
# 4              954.0               0.78              0.78
# 5              347.0               0.49              0.49
# 6              735.0               0.67              0.67
# 7               56.0               0.53              0.53
# 8              676.0               0.71              0.71
# 9              245.0               0.72              0.72
# 10             175.0               0.89              0.89
# 11             135.0               0.73              0.73
# 12             602.0               0.73              0.73
# 13             712.0               0.74              0.74
# 14            1553.0               0.75              0.75
# 15              45.0               0.70              0.70
# 16             111.0               0.88              0.88
# 17             128.0               0.72              0.72
# 18             118.0               0.88              0.88
# 19              57.0               0.60              0.60
# 20              87.0               0.82              0.82
# 21             123.0               0.73              0.73
# 22             122.0               0.88              0.88
# 23             385.0               0.90              0.90
# 24             119.0               0.89              0.89
# 25              40.0               0.87              0.87
# 26             211.0               0.91              0.91
# 27             306.0               0.75              0.75
# 28             936.0               0.79              0.79
# 29             445.0               0.66              0.66
# 30             343.0               0.70              0.70
# 31             107.0               0.88              0.88
# 32             199.0               0.82              0.82
# 33             133.0               0.87              0.87
# 34              46.0               0.98              0.98
# 35              41.0               0.85              0.85
# 36              76.0               0.59              0.59
# 37             278.0               0.40              0.40
# 38             157.0               0.23              0.23
#
#     Spawners_Two_Yrs_Prior  Eff_Catch_Two_Yrs_Prior  Fracwild_Two_Yrs_Prior
# 0                   1157.0                     0.79                    0.79
# 1                   1340.0                     0.73                    0.73
# 2                    551.0                     0.77                    0.77
# 3                    913.0                     0.77                    0.77
# 4                    347.0                     0.77                    0.77
# 5                    954.0                     0.78                    0.78
# 6                    347.0                     0.49                    0.49
# 7                    735.0                     0.67                    0.67
# 8                     56.0                     0.53                    0.53
# 9                    676.0                     0.71                    0.71
# 10                   245.0                     0.72                    0.72
# 11                   175.0                     0.89                    0.89
# 12                   135.0                     0.73                    0.73
# 13                   602.0                     0.73                    0.73
# 14                   712.0                     0.74                    0.74
# 15                  1553.0                     0.75                    0.75
# 16                    45.0                     0.70                    0.70
# 17                   111.0                     0.88                    0.88
# 18                   128.0                     0.72                    0.72
# 19                   118.0                     0.88                    0.88
# 20                    57.0                     0.60                    0.60
# 21                    87.0                     0.82                    0.82
# 22                   123.0                     0.73                    0.73
# 23                   122.0                     0.88                    0.88
# 24                   385.0                     0.90                    0.90
# 25                   119.0                     0.89                    0.89
# 26                    40.0                     0.87                    0.87
# 27                   211.0                     0.91                    0.91
# 28                   306.0                     0.75                    0.75
# 29                   936.0                     0.79                    0.79
# 30                   445.0                     0.66                    0.66
# 31                   343.0                     0.70                    0.70
# 32                   107.0                     0.88                    0.88
# 33                   199.0                     0.82                    0.82
# 34                   133.0                     0.87                    0.87
# 35                    46.0                     0.98                    0.98
# 36                    41.0                     0.85                    0.85
# 37                    76.0                     0.59                    0.59
# 38                   278.0                     0.40                    0.40

# %%
# Scale idependent variables
scaler = StandardScaler()
scaled_target = target_df [[
    'Spawners_Prev_Yr', 
    'Eff_Catch_Prev_Yr', 
    'Fracwild_Prev_Yr', 
    'Spawners_Two_Yrs_Prior',
    'Eff_Catch_Two_Yrs_Prior',
    'Fracwild_Two_Yrs_Prior']].values.tolist()

scaled_data =  scaler.fit_transform(scaled_target)
scaled_data
# Out:
# array([[ 2.67932564, -0.10651484, -0.10651484,  2.00353985,  0.24836902,
#          0.24836902],
#        [ 0.52703803,  0.16588377,  0.16588377,  2.47751194, -0.24836902,
#         -0.24836902],
#        [ 1.51452613,  0.16588377,  0.16588377,  0.43399294,  0.08278967,
#          0.08278967],
#        [-0.02944698,  0.16588377,  0.16588377,  1.37157707,  0.08278967,
#          0.08278967],
#        [ 1.62636871,  0.23398342,  0.23398342, -0.09436939,  0.08278967,
#          0.08278967],
#        [-0.02944698, -1.74090651, -1.74090651,  1.47776754,  0.16557935,
#          0.16557935],
#        [ 1.02896568, -0.51511276, -0.51511276, -0.09436939, -2.23532119,
#         -2.23532119],
#        [-0.82325648, -1.4685079 , -1.4685079 ,  0.91055504, -0.74510706,
#         -0.74510706],
#        [ 0.86802149, -0.24271415, -0.24271415, -0.84806271, -1.90416249,
#         -1.90416249],
#        [-0.30768949, -0.17461449, -0.17461449,  0.75774436, -0.41394837,
#         -0.41394837],
#        [-0.49864023,  0.98307961,  0.98307961, -0.35855055, -0.33115869,
#         -0.33115869],
#        [-0.60775493, -0.10651484, -0.10651484, -0.53985135,  1.07626576,
#          1.07626576],
#        [ 0.66615928, -0.10651484, -0.10651484, -0.64345181, -0.24836902,
#         -0.24836902],
#        [ 0.96622473, -0.03841519, -0.03841519,  0.56608352, -0.24836902,
#         -0.24836902],
#        [ 3.26036146,  0.02968446,  0.02968446,  0.85098477, -0.16557935,
#         -0.16557935],
#        [-0.85326303, -0.3108138 , -0.3108138 ,  3.02918437, -0.08278967,
#         -0.08278967],
#        [-0.67322376,  0.91497995,  0.91497995, -0.87655284, -0.49673804,
#         -0.49673804],
#        [-0.62685001, -0.17461449, -0.17461449, -0.70561208,  0.99347608,
#          0.99347608],
#        [-0.65412868,  0.91497995,  0.91497995, -0.66158189, -0.33115869,
#         -0.33115869],
#        [-0.82052861, -0.99181033, -0.99181033, -0.687482  ,  0.99347608,
#          0.99347608],
#        [-0.73869258,  0.50638203,  0.50638203, -0.8454727 , -1.32463478,
#         -1.32463478],
#        [-0.64048935, -0.10651484, -0.10651484, -0.76777236,  0.49673804,
#          0.49673804],
#        [-0.64321721,  0.91497995,  0.91497995, -0.67453195, -0.24836902,
#         -0.24836902],
#        [ 0.07421199,  1.05117926,  1.05117926, -0.67712196,  0.99347608,
#          0.99347608],
#        [-0.65140082,  0.98307961,  0.98307961,  0.00405104,  1.15905543,
#          1.15905543],
#        [-0.86690236,  0.8468803 ,  0.8468803 , -0.68489199,  1.07626576,
#          1.07626576],
#        [-0.40043699,  1.11927891,  1.11927891, -0.88950289,  0.91068641,
#          0.91068641],
#        [-0.14128956,  0.02968446,  0.02968446, -0.44661094,  1.2418451 ,
#          1.2418451 ],
#        [ 1.57726709,  0.30208308,  0.30208308, -0.20055986, -0.08278967,
#         -0.08278967],
#        [ 0.23788405, -0.58321241, -0.58321241,  1.43114733,  0.24836902,
#          0.24836902],
#        [-0.04035845, -0.3108138 , -0.3108138 ,  0.15945173, -0.82789674,
#         -0.82789674],
#        [-0.68413523,  0.91497995,  0.91497995, -0.10472944, -0.49673804,
#         -0.49673804],
#        [-0.4331714 ,  0.50638203,  0.50638203, -0.71597213,  0.99347608,
#          0.99347608],
#        [-0.61321067,  0.8468803 ,  0.8468803 , -0.47769108,  0.49673804,
#          0.49673804],
#        [-0.85053516,  1.59597648,  1.59597648, -0.64863183,  0.91068641,
#          0.91068641],
#        [-0.8641745 ,  0.71068099,  0.71068099, -0.87396282,  1.82137282,
#          1.82137282],
#        [-0.76869913, -1.05990998, -1.05990998, -0.88691288,  0.74510706,
#          0.74510706],
#        [-0.21766985, -2.35380339, -2.35380339, -0.79626248, -1.40742445,
#         -1.40742445],
#        [-0.54774184, -3.51149749, -3.51149749, -0.27308018, -2.98042825,
#         -2.98042825]])

# %%
# Create DatsFrame with scaled data
scaled_df = pd.DataFrame(
    data=scaled_data,
    columns=['Spawners_Prev_Yr_Sc', 
        'Eff_Catch_Prev_Yr_Sc', 
        'Fracwild_Prev_Yr_Sc', 
        'Spawners_Two_Yrs_Prior_Sc',
        'Eff_Catch_Two_Yrs_Prior_Sc',
        'Fracwild_Two_Yrs_Prior_Sc'],
    index=target_df.index)

# %%
# Delete columns of unscaled independent variables
target_df.drop(columns = [
    'Spawners_Prev_Yr', 
    'Eff_Catch_Prev_Yr', 
    'Fracwild_Prev_Yr', 
    'Spawners_Two_Yrs_Prior',
    'Eff_Catch_Two_Yrs_Prior',
    'Fracwild_Two_Yrs_Prior'],
    inplace=True)

# Combine target_df and scaled_df
scaled_target_df = pd.merge(target_df, scaled_df, left_index=True, right_index=True)
scaled_target_df.head()
# Out:
#    Brood_Year                                Nwr_Population_Name  \
# 0        1972  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 1        1973  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 2        1974  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 3        1975  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
# 4        1976  Chinook Salmon (Puget Sound ESU) - Mid-Hood Canal
#
#    Number_Of_Spawners  Start_Year  End_Year  Effective_Catch  Fracwild  \
# 0               551.0         NaN       NaN           2779.0      0.77
# 1               913.0         NaN       NaN           6988.0      0.77
# 2               347.0         NaN       NaN           1278.0      0.77
# 3               954.0         NaN       NaN           4596.0      0.78
# 4               347.0         NaN       NaN           1144.0      0.49
#
#    Spawners_Prev_Yr_Sc  Eff_Catch_Prev_Yr_Sc  Fracwild_Prev_Yr_Sc  \
# 0             2.679326             -0.106515            -0.106515
# 1             0.527038              0.165884             0.165884
# 2             1.514526              0.165884             0.165884
# 3            -0.029447              0.165884             0.165884
# 4             1.626369              0.233983             0.233983
#
#    Spawners_Two_Yrs_Prior_Sc  Eff_Catch_Two_Yrs_Prior_Sc  \
# 0                   2.003540                    0.248369
# 1                   2.477512                   -0.248369
# 2                   0.433993                    0.082790
# 3                   1.371577                    0.082790
# 4                  -0.094369                    0.082790
#
#    Fracwild_Two_Yrs_Prior_Sc
# 0                   0.248369
# 1                  -0.248369
# 2                   0.082790
# 3                   0.082790
# 4                   0.082790

# %%
# Create our Feature
X = target_df.drop(columns = ['Nwr_Population_Name', 'Start_Year', 'End_Year', 'Effective_Catch', 'Fracwild', 'Number_Of_Spawners'])

# Create our Target
y = target_df["Number_Of_Spawners"]

# %%
# Split data into test and train
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#Counter(y_train)

# %%
# Set up a regression ML model
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# %%
# Score the model
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# Square root of the mean squared
print('Root Mean Squared error of is:',np.sqrt(mean_squared_error(y_test,y_pred)))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [-12.52925653]
# Mean squared error: 41759.19
# Root Mean Squared error of is: 204.3506438785857
# Coefficient of determination: 0.27

# %%
# year = target_df.Brood_Year.values.reshape(-1, 1)

# %%
# plt.scatter(year, y)
# plt.plot(year, y_pred, color='red')
# plt.show()
